# %% [markdown]
# # GetAround — Pricing Prediction

# %% [markdown]
# ## Objective:
#  - Predict the optimal daily rental price of a vehicle
#  - Compare several machine learning models
#  - Select the best-performing pipeline
#  - Export the model for production (FastAPI)

# %% [markdown]
# ## 1. Imports

# %%
import os
import json
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder

from sklearn.dummy import DummyRegressor
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import xgboost as xgb
import joblib
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Configuration

# %%
DATA_URL = "https://full-stack-assets.s3.eu-west-3.amazonaws.com/Deployment/get_around_pricing_project.csv"
API_DIR = "../api"
RANDOM_STATE = 42
TEST_SIZE = 0.2

os.makedirs(API_DIR, exist_ok=True)

# %% [markdown]
# ## 3. Load Dataset

# %%
df = pd.read_csv(DATA_URL)

print("Dataset shape:", df.shape)
display(df.head())
# Out:
# Dataset shape: (4843, 15)
#    Unnamed: 0 model_key  mileage  engine_power    fuel paint_color  \
# 0           0   Citroën   140411           100  diesel       black
# 1           1   Citroën    13929           317  petrol        grey
# 2           2   Citroën   183297           120  diesel       white
# 3           3   Citroën   128035           135  diesel         red
# 4           4   Citroën    97097           160  diesel      silver
#
#       car_type  private_parking_available  has_gps  has_air_conditioning  \
# 0  convertible                       True     True                 False
# 1  convertible                       True     True                 False
# 2  convertible                      False    False                 False
# 3  convertible                       True     True                 False
# 4  convertible                       True     True                 False
#
#    automatic_car  has_getaround_connect  has_speed_regulator  winter_tires  \
# ...

# %% [markdown]
# ## 4. Data Overview

# %%
print("=== DATA TYPES ===")
print(df.info())
# Out:
# === DATA TYPES ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4843 entries, 0 to 4842
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 4843 non-null   int64
#  1   model_key                  4843 non-null   object
#  2   mileage                    4843 non-null   int64
#  3   engine_power               4843 non-null   int64
#  4   fuel                       4843 non-null   object
#  5   paint_color                4843 non-null   object
#  6   car_type                   4843 non-null   object
#  7   private_parking_available  4843 non-null   bool
#  8   has_gps                    4843 non-null   bool
#  9   has_air_conditioning       4843 non-null   bool
#  10  automatic_car              4843 non-null   bool
#  11  has_getaround_connect      4843 non-null   bool
#  12  has_speed_regulator        4843 non-null   bool
# ...

# %%
print("=== MISSING VALUES ===")
display(df.isnull().sum().sort_values(ascending=False))
# Out:
# === MISSING VALUES ===
# Unnamed: 0                   0
# model_key                    0
# mileage                      0
# engine_power                 0
# fuel                         0
# paint_color                  0
# car_type                     0
# private_parking_available    0
# has_gps                      0
# has_air_conditioning         0
# automatic_car                0
# has_getaround_connect        0
# has_speed_regulator          0
# winter_tires                 0
# rental_price_per_day         0
# dtype: int64

# %%
print("=== DUPLICATES ===")
print(df.duplicated().sum())
# Out:
# === DUPLICATES ===
# 0

# %%
print("=== TARGET STATISTICS ===")
display(df["rental_price_per_day"].describe())
# Out:
# === TARGET STATISTICS ===
# count    4843.000000
# mean      121.214536
# std        33.568268
# min        10.000000
# 25%       104.000000
# 50%       119.000000
# 75%       136.000000
# max       422.000000
# Name: rental_price_per_day, dtype: float64

# %%
print("=== CATEGORICAL FEATURES ===")
categorical_preview = df.select_dtypes(include="object").columns.tolist()
for col in categorical_preview:
    print(f"\n{col} — {df[col].nunique()} unique values")
    print(df[col].value_counts(dropna=False).head(10))
# Out:
# === CATEGORICAL FEATURES ===
#
# model_key — 28 unique values
# model_key
# Citroën       969
# Renault       916
# BMW           827
# Peugeot       642
# Audi          526
# Nissan        275
# Mitsubishi    231
# Mercedes       97
# Volkswagen     65
# Toyota         53
# Name: count, dtype: int64
#
# fuel — 4 unique values
# fuel
# diesel           4641
# petrol            191
# hybrid_petrol       8
# electro             3
# Name: count, dtype: int64
#
# paint_color — 10 unique values
# paint_color
# black     1633
# grey      1175
# blue       710
# white      538
# brown      341
# silver     329
# red         52
# beige       41
# green       18
# orange       6
# Name: count, dtype: int64
#
# car_type — 8 unique values
# car_type
# estate         1606
# sedan          1168
# suv            1058
# hatchback       699
# subcompact      117
# coupe           104
# convertible      47
# van              44
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Exploratory Visualisations

# %%
plt.figure(figsize=(10, 5))
plt.hist(df["rental_price_per_day"], bins=50, edgecolor="black")
plt.axvline(df["rental_price_per_day"].mean(), linestyle="--", label=f"Mean: {df['rental_price_per_day'].mean():.1f}")
plt.axvline(df["rental_price_per_day"].median(), linestyle="--", label=f"Median: {df['rental_price_per_day'].median():.1f}")
plt.title("Distribution of Rental Price per Day")
plt.xlabel("Price (€)")
plt.ylabel("Frequency")
plt.legend()
plt.show()

if "car_type" in df.columns:
    plt.figure(figsize=(12, 6))
    (
        df.groupby("car_type")["rental_price_per_day"]
        .mean()
        .sort_values(ascending=False)
        .plot(kind="bar")
    )
    plt.title("Average Rental Price by Car Type")
    plt.xlabel("Car Type")
    plt.ylabel("Average Price (€)")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

numeric_cols = df.select_dtypes(include=["number", "bool"]).columns.tolist()
if "rental_price_per_day" in numeric_cols:
    corr = df[numeric_cols].corr(numeric_only=True)["rental_price_per_day"].sort_values(ascending=False)
    print("=== CORRELATION WITH TARGET ===")
    display(corr)
# Out:
# === CORRELATION WITH TARGET ===
# rental_price_per_day         1.000000
# engine_power                 0.625645
# automatic_car                0.419761
# has_getaround_connect        0.318486
# has_gps                      0.310889
# private_parking_available    0.281358
# Unnamed: 0                   0.246809
# has_air_conditioning         0.245386
# has_speed_regulator          0.227547
# winter_tires                 0.018277
# mileage                     -0.448912
# Name: rental_price_per_day, dtype: float64

# %%
brand_prices = df.groupby('model_key')['rental_price_per_day'].mean().sort_values(ascending=False)

plt.figure(figsize=(14, 6))
brand_prices.plot(kind='bar', color='steelblue', edgecolor='white')
plt.title('Average rental price per day by brand')
plt.ylabel('Price (€)')
plt.xlabel('Brand')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Correlation of numeric variables with price
numeric_cols = df.select_dtypes(include='number').columns
corr = df[numeric_cols].corr()['rental_price_per_day'].sort_values(ascending=False)
print("=== CORRELATION WITH TARGET ===")
print(corr)

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df[numeric_cols].corr(), annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Correlation matrix')
plt.show()
# Out:
# === CORRELATION WITH TARGET ===
# rental_price_per_day    1.000000
# engine_power            0.625645
# Unnamed: 0              0.246809
# mileage                -0.448912
# Name: rental_price_per_day, dtype: float64

# %% [markdown]
# ## 6. Data Preparation

# %%
# Remove potential index column
if "Unnamed: 0" in df.columns:
    df = df.drop(columns=["Unnamed: 0"])

# %%
X = df.drop(columns=["rental_price_per_day"])
y = df["rental_price_per_day"]

print("Features shape:", X.shape)
print("Target shape:", y.shape)

# %%
numeric_features = X.select_dtypes(include=["number"]).columns.tolist()
categorical_features = X.select_dtypes(include=["object"]).columns.tolist()
bool_features = X.select_dtypes(include=["bool"]).columns.tolist()

# Treat booleans as numeric
numeric_features = numeric_features + [col for col in bool_features if col not in numeric_features]

print("Numeric features:", numeric_features)
print("Categorical features:", categorical_features)
# Out:
# Features shape: (4843, 13)
# Target shape: (4843,)
# Numeric features: ['mileage', 'engine_power', 'private_parking_available', 'has_gps', 'has_air_conditioning', 'automatic_car', 'has_getaround_connect', 'has_speed_regulator', 'winter_tires']
# Categorical features: ['model_key', 'fuel', 'paint_color', 'car_type']

# %% [markdown]
# ## 7. Train/Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE
)

# %%
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# --- Baseline 1: median prediction ---
dummy = DummyRegressor(strategy="median")
dummy.fit(X_train, y_train)
y_pred_dummy = dummy.predict(X_test)
rmse_dummy = np.sqrt(mean_squared_error(y_test, y_pred_dummy))
r2_dummy = r2_score(y_test, y_pred_dummy)

# --- Baseline 2: linear regression ---
lr = LinearRegression()
lr.fit(X_train_encoded, y_train)  # adapt depending on your pipeline
y_pred_lr = lr.predict(X_test_encoded)
rmse_lr = np.sqrt(mean_squared_error(y_test, y_pred_lr))
r2_lr = r2_score(y_test, y_pred_lr)

print(f"Baseline (median)    : RMSE={rmse_dummy:.2f}, R²={r2_dummy:.3f}")
print(f"Linear regression    : RMSE={rmse_lr:.2f}, R²={r2_lr:.3f}")
print(f"XGBoost              : RMSE=16.60, R²=0.738")
print(f"\nXGBoost gain vs median baseline: +{r2_dummy - 0.738:.3f} R²")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 15
#      13 # --- Baseline 2: linear regression ---
#      14 lr = LinearRegression()
# ---> 15 lr.fit(X_train_encoded, y_train)  # adapt depending on your pipeline
#      16 y_pred_lr = lr.predict(X_test_encoded)
#      17 rmse_lr = np.sqrt(mean_squared_error(y_test, y_pred_lr))
#
# NameError: name 'X_train_encoded' is not defined

# %% [markdown]
# ## 8. Preprocessing Pipeline

# %%
numeric_transformer = Pipeline([
    ("scaler", StandardScaler())
])

categorical_transformer = Pipeline([
    ("encoder", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
])

preprocessor = ColumnTransformer([
    ("num", numeric_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features)
])

# %% [markdown]
# ## 9. Model Benchmarking

# %%
models = {
    "DummyMean": DummyRegressor(strategy="mean"),
    "Ridge": Ridge(alpha=1.0),
    "RandomForest": RandomForestRegressor(n_estimators=100, random_state=RANDOM_STATE, n_jobs=-1),
    "GradientBoosting": GradientBoostingRegressor(random_state=RANDOM_STATE),
    "XGBoost": xgb.XGBRegressor(random_state=RANDOM_STATE, verbosity=0)
}

results = {}

for name, model in models.items():
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("model", model)
    ])
    
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    cv_scores = cross_val_score(
        pipe,
        X_train,
        y_train,
        cv=5,
        scoring="neg_root_mean_squared_error",
        n_jobs=-1
    )
    
    results[name] = {
        "RMSE": rmse,
        "MAE": mae,
        "R²": r2,
        "CV_RMSE_mean": -cv_scores.mean(),
        "CV_RMSE_std": cv_scores.std()
    }
    
    print(
        f"{name:20s} → RMSE: {rmse:.2f} | MAE: {mae:.2f} | R²: {r2:.3f} | CV RMSE: {-cv_scores.mean():.2f}"
    )

df_results = pd.DataFrame(results).T.sort_values("RMSE")
print("\n=== MODEL RANKING ===")
display(df_results)
# Out:
# DummyMean            → RMSE: 32.46 | MAE: 23.26 | R²: -0.001 | CV RMSE: 33.82
# Ridge                → RMSE: 17.97 | MAE: 12.12 | R²: 0.693 | CV RMSE: 18.43
# RandomForest         → RMSE: 16.75 | MAE: 10.69 | R²: 0.734 | CV RMSE: 16.82
# GradientBoosting     → RMSE: 17.03 | MAE: 11.37 | R²: 0.725 | CV RMSE: 17.35
# XGBoost              → RMSE: 16.60 | MAE: 10.50 | R²: 0.738 | CV RMSE: 16.86
#
# === MODEL RANKING ===
#                        RMSE        MAE        R²  CV_RMSE_mean  CV_RMSE_std
# XGBoost           16.602762  10.496041  0.738278     16.862180     1.267468
# RandomForest      16.753114  10.694613  0.733516     16.816787     1.761883
# GradientBoosting  17.031475  11.370657  0.724587     17.354379     1.953376
# Ridge             17.968919  12.119205  0.693435     18.427887     1.853223
# DummyMean         32.463485  23.257965 -0.000621     33.824215     1.280714

# %% [markdown]
# ## 10. Select Best Model

# %%
best_model_name = df_results.index[0]
print("Best model:", best_model_name)

final_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("model", models[best_model_name])
])

final_pipeline.fit(X_train, y_train)
# Out:
# Best model: XGBoost
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['mileage', 'engine_power',
#                                                    'private_parking_available',
#                                                    'has_gps',
#                                                    'has_air_conditioning',
#                                                    'automatic_car',
#                                                    'has_getaround_connect',
#                                                    'has_speed_regulator',
#                                                    'winter_tires']),
#                                                  ('cat',
# ...

# %%
best_model_name = df_results.index[0]
print(f"Best model: {best_model_name}")

final_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', models[best_model_name])
])

final_pipeline.fit(X_train, y_train)

import os
os.makedirs('../api', exist_ok=True)

joblib.dump(final_pipeline, '../api/pipeline.pkl')
print("✅ Pipeline saved to ../api/pipeline.pkl")
# Out:
# Best model: XGBoost
# ✅ Pipeline saved to ../api/pipeline.pkl

# %% [markdown]
# ## 11. Save Model for API

# %%
joblib.dump(final_pipeline, f"{API_DIR}/pipeline.pkl")
print("Pipeline saved")

# %%
feature_names = X.columns.tolist()

with open(f"{API_DIR}/feature_names.json", "w") as f:
    json.dump(feature_names, f)

print("Feature names saved")

# %%
best_metrics = df_results.loc[best_model_name].to_dict()

with open(f"{API_DIR}/model_metrics.json", "w") as f:
    json.dump(best_metrics, f)

print("Model metrics saved")
# Out:
# Pipeline saved
# Feature names saved
# Model metrics saved

# %% [markdown]
# ## 12. Conclusion

# %% [markdown]
# - Several models were compared using RMSE, MAE and R²
# - Cross-validation was used to ensure robustness
# - The best model was selected automatically
# - A full pipeline (preprocessing + model) was exported for production use

# %% [markdown]
# #
